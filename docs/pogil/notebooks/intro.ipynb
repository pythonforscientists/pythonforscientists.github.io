# %% [markdown]
# # Introduction to POGIL- Google Colab and IPYNBs
#
# ## Python for Scientists

# %% [markdown]
# In this course, you will work in teams of 3 or 4 to learn new concepts. This activity will introduce you to the process. We'll first take a look at variables, assignments, and input/output.

# %% [markdown]
# ### Content Learning Objectives

# %% [markdown]
#  After completing this activity, students should be able to:
#
# - Describe differences between program and output text
# - Identify and execute Python functions for input/output
# - Write assignment statements and use assigned variables

# %% [markdown]
# ### Process Skill Goals

# %% [markdown]
# During this activity, you should make progress toward:
#
# - Leveraging prior knowledge and experience of other students

# %% [markdown]
# ### Task 1

# %% [markdown]
# **You've just opened a file called POGIL 1.1 - Introduction to Python - Colab and IPYNBs. This particular file is something called a Jupyter Notebook. A Jupyter Notebook is a very common tool for data scientists and Python programmers, and it lets you run code inline with your document.**
#
# **You'll get a more thourough lab in using and creating a Jupyter Notebook (Lab 0), but for now, you can just edit a copy of this file.**
#
# **Google Colab is a tool that lets you edit and run code inside of an interactive Python notebook, or IPYNB. A Jupyter Notebook is just one kind of IPYNB.**

# %% [markdown]
# **Right now, you're reading a text block. This is just regular text that can't be run. But, the next block is for code. If you hover over the code block, you'll see a play button to the very left of the block. If you click on this button, you can run the code! Try it out!**

# %%
# <- click on that play button

# display a welcome message
print("Welcome to Python 3 in a Jupyter Notebook!")

# give the user a compliment
name = input("What is your name? ")
print(name, "is a great name!")

# %% [markdown]
# **Here's some code, but it's written in a text block. Can you run it like you did the code above? Why not?**
#
# ```python
# # display a welcome message
# print("Welcome to Python 3 in a Jupyter Notebook!")
#
# # give the user a compliment
# name = input("What is your name? ")
# print(name, "is a great name!")
# ```

# %% [markdown]
# **Now, here's an empty code block. Try to copy and paste that unrunnable code from just above to this empty block. Can you run it now?**

# %%
# display a welcome message
print("Welcome to Python 3 in a Jupyter Notebook!")
 
# give the user a compliment
name = input("What is your name? ")
print(name, "is a great name!")

# %% [markdown]
# **Here's some code, but it's written in a text block. Can you run it like you did the code above? Why not?**
#
# ```python
# # display a welcome message
# print("Welcome to Python 3 in a Jupyter Notebook!")
#
# # give the user a compliment
# name = input("What is your name? ")
# print(name, "is a great name!")
# ```

# %% [markdown]
# **Here's some code, but it's written in a text block. Can you run it like you did the code above? Why not?**
#
# ```python
# # display a welcome message
# print("Welcome to Python 3 in a Jupyter Notebook!")
#
# # give the user a compliment
# name = input("What is your name? ")
# print(name, "is a great name!")
# ```

# %% [markdown]
# **In the previous example, what was the executable code?**

# %% [markdown]
# **What was the output?** Paste it here:

# %% [markdown]
# ### Task 2

# %% [markdown]
# **Consider the code from Task 1. What is the symbol at the start of a line in the code that was not displayed as output?**

# %% [markdown]
# ### Task 3

# %% [markdown]
# **Consider the three program lines that are not displayed as output. Describe what might be the purpose of:**
#
# **a comment line**

# %% [markdown]
# **a blank line**

# %% [markdown]
# ### Task 4

# %% [markdown]
# **What was required before the third line of the program output was displayed? As a reminder, the third line that didn't get executed until this happened was:**
#
# ```python
# print(name, "is a great name!")
# ```

# %% [markdown]
# ### Task 5

# %% [markdown]
# **Describe what appears to be the purpose of each of the following lines of Python code.**
#
# ```python
# # display a welcome message
# ```

# %% [markdown]
# ```python
# print("Welcome to Python 3 in a Jupyter Notebook!")
# ```

# %% [markdown]
# ```
# (a blank line)
# ```

# %% [markdown]
# ```python
# # give the user a compliment
# ```

# %% [markdown]
# ```python
# name = input("What is your name? ")
# ```

# %% [markdown]
# ```python
# print(name, "is a great name!")
# ```

# %% [markdown]
# ### Task 6

# %% [markdown]
# **Recall: What character turns a line into a comment? Do comments get executed by the Python interpreter?**

# %% [markdown]
# **Consider the following code:**
#
# ```python
# print("          (__)")
# print("          (oo)")
# print("")
# print("")
# print("")
# print("")
# print("   /-------\\/")
# print("  / |     ||")
# print(" *  ||----||")
# print("    ^^    ^^")
# ```
#
# **Try running this code. What does it print?**

# %% [markdown]
# **Using your special commenting character, comment out all of the lines that are separating the cow's head from its body. Don't delete any code! Write your commented code below.**

# %% [markdown]
# **It was only four lines that you had to comment out, but what if it were more lines? That'd be really tedious! Thankfully, Python has a way to comment out multiple lines at once. This is known in programming as a *block comment*.**
#
# **Paste in the starting code from before. This time, make an extra line before the code you want to start commenting out and after the last line of code you want commented out. This time, in those blank lines, put three quotation marks. Run the code again. What happened?**

# %% [markdown]
# You can comment out a block of code using a block comment. This looks like:
#
# ```python
# """
# print("This is commented out.")
# print("This won't print.")
# """
# print("but this will.")
# ```

# %% [markdown]
# ---
#
# End of exercise.
